# %%
for repetidor in range(11): #sabemos que el "for in range" nos sirve para repetir una acción dentro de un rango de valores  
  print(repetidor * "1")    #en este caso ocupamos la variable "repetidor" para la iteracion del valor y así mimsmo la cantidad de veces que repite "1"
# Out:
# 1
# 11
# 111
# 1111
# 11111
# 111111
# 1111111
# 11111111
# 111111111
# 1111111111

# %% [markdown]
# # Calificación: 7.0
